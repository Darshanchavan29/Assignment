# %% [markdown]
# Q1. Explain GET and POST methods.

# %%
"""
GET and Post are two Route methods usually used to request object methods by default GET method is used
but we can use POST method by mentioning it in the route decorator 


Flask Request GET: method send unencrypted data to the target script throught URL for processing
data is unencrypted so visible in the URL, Usually used in google for search
your search keyword generally shown in URL in the browser and same visible in routing 
GET Method is default method in flask but if we want to initialize at our then then syntax is: 

@app.route('/url', methods = ["GET"])
def our_function():
    statements....
ON html side to need some mentioning of GET method like 
<form method = "GET" action = {{url_for('url')}}>
    var = request.form.get('sub')
    some html tags and all 
</form>

POST: HTTP Post method sends encrypted data to the requested script. when FLask POST is used form data 
collected from the requesting form and passed on to the scritp. This data is not sent along with url as args. 
data is not visible in URL but values can be accessed in the script by using request.form.get
Syntax : 

@app.route('/url', methods = ["POST"])
def our_function():
    var = request.form.get('sub')
    some statement....
ON html side
<form method = "POST" actio.......>

"""
# Out:
# '\nGET and Post are two Route methods usually used to request object methods by default GET method is used\nbut we can use POST method by mentioning it in the route decorator \n\n\nFlask Request GET: method send unencrypted data to the target script throught URL for processing\ndata is unencrypted so visible in the URL, Usually used in google for search\nyour search keyword generally shown in URL in the browser and same visible in routing \nGET Method is default method in flask but if we want to initialize at our then then syntax is: \n\n@app.route(\'/url\', methods = ["GET"])\ndef our_function():\n    statements....\nON html side to need some mentioning of GET method like \n<form method = "GET" action = {{url_for(\'url\')}}>\n    var = request.form.get(\'sub\')\n    some html tags and all \n</form>\n\nPOST: HTTP Post method sends encrypted data to the requested script. when FLask POST is used form data \ncollected from the requesting form and passed on to the scritp. This data is no
# ...

# %% [markdown]
# Q2. Why is request used in Flask?

# %%
"""
Request in flask is an object that contain all the data sent from the client to server. This data can be 
recovered by using GET/POST methods. 
Request offers various attributes associated with to improve functionality like 
Form, Cookies, Args, Files and methods. all these are self explanatory like form used to fetch data from html form tagas
method used to fetch methods and soo on

basic syntax is: 
request.form.get('sub')
request.methods('methods')
.....

"""
# Out:
# "\nRequest in flask is an object that contain all the data sent from the client to server. This data can be \nrecovered by using GET/POST methods. \nRequest offers various attributes associated with to improve functionality like \nForm, Cookies, Args, Files and methods. all these are self explanatory like form used to fetch data from html form tagas\nmethod used to fetch methods and soo on\n\nbasic syntax is: \nrequest.form.get('sub')\nrequest.methods('methods')\n.....\n\n"

# %% [markdown]
# Q3. Why is redirect() used in Flask?

# %%
"""
redirect is used in flask class to sent the user to a particular URL with the status code.
like when we try to login to any website it redirect us to Google login APIs once we logged in it redirect backt to 
home page or whatever page we are trying to access 
Syntax of redirect: 
flask.redirect(location, code = 302)
where Location(str): location of url which direct to
code(int): status code for redirect. here we use default code 302 which means that the move is only temporary

code: 
#default page opens which redirect us to next i.e helloWorld
@app.route('/')
def home():
    return redirect('/helloWorld')
    
#to this
@app.route('/helloWorld')
def hellow():
    return "<p> hello, World from \
            redirected page.!</p>"
        

"""
# Out:
# '\nredirect is used in flask class to sent the user to a particular URL with the status code.\nlike when we try to login to any website it redirect us to Google login APIs once we logged in it redirect backt to \nhome page or whatever page we are trying to access \nSyntax of redirect: \nflask.redirect(location, code = 302)\nwhere Location(str): location of url which direct to\ncode(int): status code for redirect. here we use default code 302 which means that the move is only temporary\n\ncode: \n#default page opens which redirect us to next i.e helloWorld\n@app.route(\'/\')\ndef home():\n    return redirect(\'/helloWorld\')\n    \n#to this\n@app.route(\'/helloWorld\')\ndef hellow():\n    return "<p> hello, World from             redirected page.!</p>"\n        \n\n'

# %% [markdown]
# Q4. What are templates in Flask? Why is the render_template() function used?

# %%
"""
Templates are just a text file which contains static HTML code as well as some special markup dynamic content
that will be known at the time of request.
Flask Comes bundled with template engine called Jinja which does the job of parsing templates and converting them to flat HTML page.

Rendering Templates: 
To render a template in Flask, you can use the render_template function, which is provided by 
Flask. This function takes the name of the template file as its first argument and any additional
variables that you want to pass to the template as keyword arguments
Or render_template() help us to sent data from flask to client after processing using html 
render_template sent values of keyword which recieved by html and showcased 

ex. consider we want to show Name value is Jerry then html code be 
....some tag....
    <p> Name: Jerry</p>
... some tag....
if we want to pass this using flask template ie. render_template() then 
....some tag....
    <p>{name}</p>
... some tag....
and in flask python file 

@app.route('/')
def index():
    return render_template('index.html', name = 'Jerry')
#......

index.html refers to our html file and flask file name pass on Jerry to html name implicitly

"""
# Out:
# "\nTemplates are just a text file which contains static HTML code as well as some special markup dynamic content\nthat will be known at the time of request.\nFlask Comes bundled with template engine called Jinja which does the job of parsing templates and converting them to flat HTML page.\n\nRendering Templates: \nTo render a template in Flask, you can use the render_template function, which is provided by \nFlask. This function takes the name of the template file as its first argument and any additional\nvariables that you want to pass to the template as keyword arguments\nOr render_template() help us to sent data from flask to client after processing using html \nrender_template sent values of keyword which recieved by html and showcased \n\nex. consider we want to show Name value is Jerry then html code be \n....some tag....\n    <p> Name: Jerry</p>\n... some tag....\nif we want to pass this using flask template ie. render_template() then \n....some tag....\n    <p>{name}</p>\n..
# ...

# %% [markdown]
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %%
from flask import Flask, request

app = Flask(__name__)

@app.route('/greet')
def greet():
  name = request.args.get('name')
  message = f'Hello, {name}!'
  return message

if __name__ == '__main__':a
  app.run(debug=True)

# %% [markdown]
# ![Screenshot 2023-06-30 110205.png](attachment:5a27938b-9425-4f11-a80e-b736625d330a.png)
